# %% [markdown]
# ## visualizing n-dimensional data using 3D surface plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plotsurface(data):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(data, Y=data,Z=data,cmap='jet')
    
data = np.random.rand(10,100)

plotsurface(data)

# %% [markdown]
# ## Best first search

# %%
import heapq

def bestfirstsearch(graph,start,goal):
    frontier = [(0,start)]
    explored = set()
    
    while frontier:
        (cost,current_node) = heapq.heappop(frontier)
        
        if current_node == goal:
            return cost
        
        explored.add(current_node)
        print(f"explored node: {current_node}")
        
        for neighbor, neighbor_cost in graph[current_node]:
            if neighbor not in explored and neighbor not in [node[1] for node in frontier]:
                heapq.heappush(frontier,(neighbor_cost+cost, neighbor))
                print(f"added node {neighbor} to frontier with cost{neighbor_cost}")
                
    return None

graph = {
    'A': [('B', 5), ('C', 6)],
    'B': [('D', 4), ('E', 7)],
    'C': [('F', 9), ('G', 8)],
    'D': [('H', 3)],
    'E': [('I', 6)],
    'F': [('J', 5)],
    'G': [('K', 7)],
    'H': [('L', 1)],
    'I': [('M', 2)],
    'J': [('N', 3)],
    'K': [('O', 4)],
    'L': [],
    'M': [],
    'N': [],
    'O': [('P', 1)],
    'P': []
}


start  = input("enter the start node: ")
goal = input("Enter the goal node: ")

result = bestfirstsearch(graph, start,goal)

if result is not None:
    print(f"The minimum cost from {start} to {goal} is {result}")
else:
    print("There is no path")
# Out:
# enter the start node: A
# Enter the goal node: P
# explored node: A
# added node B to frontier with cost5
# added node C to frontier with cost6
# explored node: B
# added node D to frontier with cost4
# added node E to frontier with cost7
# explored node: C
# added node F to frontier with cost9
# added node G to frontier with cost8
# explored node: D
# added node H to frontier with cost3
# explored node: E
# added node I to frontier with cost6
# explored node: H
# added node L to frontier with cost1
# explored node: L
# explored node: G
# added node K to frontier with cost7
# explored node: F
# added node J to frontier with cost5
# explored node: I
# added node M to frontier with cost2
# explored node: J
# added node N to frontier with cost3
# explored node: M
# explored node: K
# added node O to frontier with cost4
# explored node: N
# explored node: O
# added node P to frontier with cost1
# The minimum cost from A to P is 26
